# %%
   import matplotlib.pyplot as plt
   import seaborn as sns
   df=pd.read_csv('D:/result sheet cs')

   # Assuming 'df' is your DataFrame with the dataset
   sns.scatterplot(x='CreditCardLimit', y='AveragePurchase', data=df)
   plt.title('Correlation between Credit Card Limit and Average Purchase')
   plt.xlabel('Credit Card Limit')
   plt.ylabel('Average Purchase')
   plt.show()
   


   # Creating box plots
   sns.boxplot(x='CreditCardLimit', data=df)
   plt.title('Distribution of Credit Card Limit')
   plt.xlabel('Credit Card Limit')
   plt.show()

   sns.boxplot(x='AveragePurchase', data=df)
   plt.title('Distribution of Average Purchase')
   plt.xlabel('Average Purchase')
   plt.show()
   


   sns.countplot(x='IncomeGroup', data=df)
   plt.title('Number of Customers in Each Income Group')
   plt.xlabel('Income Group')
   plt.ylabel('Number of Customers')
   plt.xticks(rotation=45)
   plt.show()
   


   plt.hist(df['TotalTransactionAmount'], bins=20)
   plt.title('Frequency Distribution of Total Transaction Amount')
   plt.xlabel('Total Transaction Amount')
   plt.ylabel('Frequency')
   plt.show()
   


   # Assuming you have a column 'RetentionStatus' with values 'Retained' and 'Attrited'
   retention_counts = df['RetentionStatus'].value_counts()
   plt.pie(retention_counts, labels=retention_counts.index, autopct='%1.1f%%', startangle=90)
   plt.title('Customer Retention')
   plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 6
#       3 df=pd.read_csv('D:/result sheet cs.csv')
#       5 # Assuming 'df' is your DataFrame with the dataset
# ----> 6 sns.scatterplot(x='CreditCardLimit', y='AveragePurchase', data=df)
#       7 plt.title('Correlation between Credit Card Limit and Average Purchase')
#       8 plt.xlabel('Credit Card Limit')
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:742, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     732 def scatterplot(
#     733     data=None, *,
#     734     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     738     **kwargs
#     739 ):
#     741     variables = _ScatterPlotter.get_semantics(locals())
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
mtcars = pd.read_csv('D:\EXCEL.csv')

# Create a histogram for 'mpg'
plt.hist(mtcars['mpg'], bins=15, color='blue', alpha=0.7)
plt.xlabel('Miles per Gallon (MPG)')
plt.ylabel('Frequency')
plt.title('Histogram of MPG')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mpg'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('D:/exam.csv')


plt.figure(figsize=(8, 6))
plt.hist(df['mpg'], bins=10, edgecolor='k', alpha=0.7)
plt.xlabel('Miles per Gallon (mpg)')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of mpg')
plt.grid(True)
plt.show()


hist_values,bin_edges= np.histogram(df['mpg'], bins=10)
max_freq_interval = (bin_edges[np.argmax(hist_values)], bin_edges[np.argmax(hist_values) + 1])
print(f"Interval with highest frequency: {max_freq_interval}")


plt.figure(figsize=(8, 6))
plt.scatter(df['wt'], df['mpg'], alpha=0.7, color='blue')
plt.xlabel('Weight (1000 lbs)')
plt.ylabel('Miles per Gallon (mpg)')
plt.title('Scatter Plot: Weight vs. mpg')
plt.grid(True)
plt.show()


transmission_counts = df['am'].value_counts()
transmission_labels = ['Automatic', 'Manual']

plt.figure(figsize=(8, 6))
sns.barplot(x=transmission_labels, y=transmission_counts, palette="viridis")
plt.xlabel('Transmission Type')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of Transmission Type')
plt.show()


plt.figure(figsize=(8, 6))
plt.boxplot(df['mpg'])
plt.xlabel('Miles per Gallon (mpg)')
plt.title('Box Plot of mpg')
plt.grid(True)
plt.show()

summary = df['mpg'].describe()
print("\nFive-Number Summary for 'mpg':\n")
print(summary)
# Out:
# Interval with highest frequency: (15.100000000000001, 17.450000000000003)
# Five-Number Summary for 'mpg':
#
# count    32.000000
# mean     20.090625
# std       6.026948
# min      10.400000
# 25%      15.425000
# 50%      19.200000
# 75%      22.800000
# max      33.900000
# Name: mpg, dtype: float64
